# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
train = pd.read_csv('/content/drive/MyDrive/CS4622 - Machine Learning/Lab 01/train.csv')
valid = pd.read_csv('/content/drive/MyDrive/CS4622 - Machine Learning/Lab 01/valid.csv')
test = pd.read_csv('/content/drive/MyDrive/CS4622 - Machine Learning/Lab 01/test.csv')

# %%
train.describe()
# Out:
#           feature_1     feature_2     feature_3     feature_4     feature_5  \
# count  28520.000000  28520.000000  28520.000000  28520.000000  28520.000000
# mean      -0.225478     -0.616421     -0.212878      0.336330      0.105467
# std        0.990632      1.005573      1.075468      1.248919      0.831132
# min       -4.023911     -5.582544     -4.679888     -4.284380     -3.010300
# 25%       -0.869656     -1.287018     -0.913419     -0.478661     -0.437171
# 50%       -0.190790     -0.609782     -0.218800      0.295881      0.117310
# 75%        0.457509      0.063174      0.490262      1.119242      0.657941
# max        4.322171      3.876604      4.267163      5.828656      3.884939
#
#           feature_6     feature_7     feature_8     feature_9    feature_10  \
# count  28520.000000  28520.000000  28520.000000  28520.000000  28520.000000
# mean      -0.339634     -0.201756      0.742262      0.942325     -1.957584
# std        1.073267      0.943505      1.055721      0.940459      0.876939
# min       -5.034355     -4.355222     -3.806574     -2.922614     -5.203347
# 25%       -1.075753     -0.823699      0.064072      0.298269     -2.556436
# 50%       -0.329571     -0.193263      0.755193      0.940786     -1.949847
# 75%        0.393339      0.417146      1.461846      1.579200     -1.345999
# max        3.890622      3.799406      4.817545      4.615069      1.147192
#
#        ...   feature_251   feature_252   feature_253   feature_254  \
# count  ...  28520.000000  28520.000000  28520.000000  28520.000000
# mean   ...     -0.028098      0.296340      1.724439     -1.476765
# std    ...      0.989497      1.173378      0.968611      1.032811
# min    ...     -3.679602     -3.905801     -3.301683     -5.490267
# 25%    ...     -0.692262     -0.550897      1.121631     -2.130906
# 50%    ...     -0.018218      0.295523      1.783432     -1.449978
# 75%    ...      0.644112      1.128566      2.383575     -0.799414
# max    ...      3.915582      4.458014      5.261775      2.861117
#
#         feature_255   feature_256       label_1       label_2       label_3  \
# count  28520.000000  28520.000000  28520.000000  28040.000000  28520.000000
# mean       0.687445     -1.563062     30.498843     27.975107      0.799299
# std        1.028328      1.243758     17.328389      5.735913      0.400532
# min       -3.810144     -6.056032      1.000000     22.000000      0.000000
# 25%       -0.008394     -2.404028     15.000000     25.000000      1.000000
# 50%        0.639575     -1.650610     30.000000     27.000000      1.000000
# 75%        1.347263     -0.805710     46.000000     30.000000      1.000000
# max        5.531152      3.338544     60.000000     61.000000      1.000000
#
#             label_4
# count  28520.000000
# mean       5.997125
# std        2.375567
# min        0.000000
# 25%        6.000000
# 50%        6.000000
# 75%        6.000000
# max       13.000000
#
# [8 rows x 260 columns]

# %%
valid.describe()
# Out:
#         feature_1   feature_2   feature_3   feature_4   feature_5   feature_6  \
# count  750.000000  750.000000  750.000000  750.000000  750.000000  750.000000
# mean    -0.215982   -0.623504   -0.291264    0.377151    0.178972   -0.252002
# std      0.956326    1.035303    1.128986    1.244136    0.843049    1.069149
# min     -3.600761   -5.998218   -3.933543   -3.788818   -2.352740   -4.067048
# 25%     -0.834711   -1.307291   -0.998405   -0.422144   -0.424725   -0.992993
# 50%     -0.205673   -0.607260   -0.307802    0.326517    0.190352   -0.196757
# 75%      0.417797    0.030387    0.412266    1.156195    0.757207    0.476947
# max      2.302163    2.441009    3.116088    4.058463    2.861698    2.790602
#
#         feature_7   feature_8   feature_9  feature_10  ...  feature_251  \
# count  750.000000  750.000000  750.000000  750.000000  ...   750.000000
# mean    -0.228841    0.771239    0.922442   -1.959988  ...    -0.051848
# std      0.955363    1.074252    0.947518    0.868173  ...     0.987202
# min     -3.307670   -3.230605   -2.501911   -4.732800  ...    -2.942192
# 25%     -0.916115    0.110733    0.323182   -2.508483  ...    -0.716455
# 50%     -0.212617    0.816087    0.910706   -1.918432  ...    -0.031057
# 75%      0.429078    1.482462    1.535642   -1.396017  ...     0.617642
# max      3.414155    4.249192    3.708912    0.418425  ...     3.356440
#
#        feature_252  feature_253  feature_254  feature_255  feature_256  \
# count   750.000000   750.000000   750.000000   750.000000   750.000000
# mean      0.342457     1.691002    -1.485593     0.691309    -1.567317
# std       1.141813     0.938246     1.051536     1.004137     1.268333
# min      -2.858132    -1.695706    -4.781263    -2.499728    -5.805717
# 25%      -0.491588     1.049466    -2.149493     0.035928    -2.459352
# 50%       0.333020     1.772243    -1.503996     0.620206    -1.634017
# 75%       1.135099     2.372264    -0.847414     1.324276    -0.752141
# max       3.532709     3.927659     2.039558     4.018772     2.496667
#
#           label_1     label_2     label_3     label_4
# count  750.000000  736.000000  750.000000  750.000000
# mean    30.085333   28.330163    0.810667    6.117333
# std     17.489060    6.518500    0.392035    2.227895
# min      1.000000   22.000000    0.000000    0.000000
# 25%     15.000000   25.000000    1.000000    6.000000
# 50%     29.000000   27.000000    1.000000    6.000000
# 75%     45.000000   30.000000    1.000000    6.000000
# max     60.000000   61.000000    1.000000   13.000000
#
# [8 rows x 260 columns]

# %%
FEATURES = [f'feature_{i}' for i in range(1,257)]

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##Label 01

# %%
train1 = train[FEATURES + ['label_1']].dropna()
valid1 = valid[FEATURES + ['label_1']]

# %%
train1.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0  -1.928826  -0.291540   1.105909   2.070652   0.657838  -0.670940
# 1  -1.709277  -1.008998   0.956611   4.313823  -0.669455   1.928765
# 2  -1.906183  -0.357562  -0.682627   4.651838  -0.884940   1.159512
# 3   0.697872  -2.218567  -0.572214   1.192062   0.329554   0.741364
# 4  -1.976895  -0.496308   0.368102   3.739787  -0.132058   1.234980
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_248  feature_249  \
# 0  -0.968238   0.049916   1.111149   -1.834592  ...     1.007398    -0.317517
# 1   0.162550   0.152173   2.356505   -2.898549  ...    -1.559120    -1.369495
# 2   1.354481  -1.432248   2.160144   -3.175735  ...    -0.136551    -2.210191
# 3   0.962354   0.993512   2.896854   -1.600380  ...    -0.718073    -2.546477
# 4  -0.501003   0.881554   1.630941   -3.853953  ...    -0.739541    -1.097638
#
#    feature_250  feature_251  feature_252  feature_253  feature_254  \
# 0    -0.148447    -0.691538    -1.152522     0.441157    -1.494434
# 1    -1.253272    -0.668235    -0.532695     0.151163    -1.876885
# 2    -1.463330    -0.026728     0.440408     2.745906    -0.680754
# 3    -2.172275     0.709032     0.812106     1.055266    -0.915258
# 4    -0.574205    -0.599700    -1.024829     1.869753    -2.498570
#
#    feature_255  feature_256  label_1
# 0    -0.344974    -0.395641       45
# 1     1.651534    -2.706490       45
# 2    -0.643588    -2.587203       45
# 3    -0.924856    -1.318964       45
# 4     3.268253    -1.356606       45
#
# [5 rows x 257 columns]

# %%
from sklearn import svm

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##  without any feature engineering

# %%
scaler = StandardScaler()

# %%
_x_train1 = train1.drop('label_1',axis=1)
y_train1 = train1['label_1']

_x_valid1 = valid1.drop('label_1',axis=1)
y_valid1 = valid1['label_1']

# %%
x_train1 = pd.DataFrame(scaler.fit_transform(_x_train1),columns=FEATURES)
x_valid1 = pd.DataFrame(scaler.transform(_x_valid1),columns=FEATURES)

# %%
clf = svm.SVC(kernel='linear')
clf.fit(x_train1,y_train1)
# Out:
# SVC(kernel='linear')

# %%
y_pred = clf.predict(x_valid1)

# %%
from sklearn import metrics

# %%
def find_accuracy(Y_pred,Y_valid):
  print(f"accuracy_score {metrics.accuracy_score(Y_valid,Y_pred)}")
  print(f"precision_score {metrics.precision_score(Y_valid,Y_pred,average='weighted')}")
  print(f"recall_score {metrics.recall_score(Y_valid,Y_pred,average='weighted')}")

# %%
find_accuracy(y_pred,y_valid1)
# Out:
# accuracy_score 0.9906666666666667
# precision_score 0.9914608132608133
# recall_score 0.9906666666666667

# %% [markdown]
# ## Feature selection

# %% [markdown]
# ### Mutual Information Feature selection

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif
import numpy as np

# %%
for k in [50,200,250]:
  mutual_info_selector = SelectKBest(mutual_info_classif, k=k)
  x_train_mutual_info = mutual_info_selector.fit_transform(x_train1, y_train1)
  print(f"Selected featured: ", x_train_mutual_info.shape[1])

  clf = svm.SVC(kernel='linear')
  clf.fit(x_train_mutual_info,y_train1)
  y_pred = clf.predict(mutual_info_selector.transform(x_valid1))

  print(f"Accuracies for k={k}: ")
  find_accuracy(y_pred,y_valid1)
# Out:
# Selected featured:  50
# Accuracies for k=50:
# accuracy_score 0.94
# precision_score 0.9450196804571416
# recall_score 0.94
# Selected featured:  200
# Accuracies for k=200:
# accuracy_score 0.9893333333333333
# precision_score 0.9901360269360269
# recall_score 0.9893333333333333
# Selected featured:  250
# Accuracies for k=250:
# accuracy_score 0.9906666666666667
# precision_score 0.9915571095571095
# recall_score 0.9906666666666667

# %% [markdown]
# k = 230

# %%
mutual_info_selector = SelectKBest(mutual_info_classif, k=230)
x_train_mutual_info = mutual_info_selector.fit_transform(x_train1, y_train1)
print(f"Selected featured: ", x_train_mutual_info.shape[1])

clf = svm.SVC(kernel='linear')
clf.fit(x_train_mutual_info,y_train1)
y_pred = clf.predict(mutual_info_selector.transform(x_valid1))

print(f"Accuracies for k={230}: ")
find_accuracy(y_pred,y_valid1)
# Out:
# Selected featured:  230
# Accuracies for k=230:
# accuracy_score 0.9906666666666667
# precision_score 0.9915060728744939
# recall_score 0.9906666666666667

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

# %%
for n in [0.95,0.99]:
  pca = PCA(n_components=n, svd_solver='full')
  pca.fit(x_train1)
  x_train_pca = pd.DataFrame(pca.transform(x_train1))
  x_valid_pca = pd.DataFrame(pca.transform(x_valid1))
  print(f"Selected featured: ", x_train_pca.shape[1])

  clf = svm.SVC(kernel='linear')
  clf.fit(x_train_pca,y_train1)
  y_pred = clf.predict(x_valid_pca)
  print(f"Accuracies for n_components={n}: ")
  find_accuracy(y_pred,y_valid1)
# Out:
# Selected featured:  67
# Accuracies for n_components=0.95:
# accuracy_score 0.9813333333333333
# precision_score 0.9835733337182255
# recall_score 0.9813333333333333
# Selected featured:  106
# Accuracies for n_components=0.99:
# accuracy_score 0.9893333333333333
# precision_score 0.9902756280756282
# recall_score 0.9893333333333333

# %% [markdown]
# ### Mutual Information Feature selection + PCA k=230, n_components=0.99

# %%
mutual_info_selector = SelectKBest(mutual_info_classif, k=230)
x_train_mutual_info = mutual_info_selector.fit_transform(x_train1, y_train1)
x_valid_mutual_info = mutual_info_selector.transform(x_valid1)
print(f"Selected featured for k=230: ", x_train_mutual_info.shape[1])

pca = PCA(n_components=0.99, svd_solver='full')
pca.fit(x_train_mutual_info)
x_train_pca = pd.DataFrame(pca.transform(x_train_mutual_info))
x_valid_pca = pd.DataFrame(pca.transform(x_valid_mutual_info))
print(f"Selected featured: ", x_train_pca.shape[1])

clf_selected = svm.SVC(kernel='linear')
clf_selected.fit(x_train_pca,y_train1)
y_pred = clf_selected.predict(x_valid_pca)
print(f"Accuracies for n_components={0.99}: ")
find_accuracy(y_pred,y_valid1)
# Out:
# Selected featured for k=230:  230
# Selected featured:  103
# Accuracies for n_components=0.99:
# accuracy_score 0.992
# precision_score 0.992575730994152
# recall_score 0.992

# %% [markdown]
# ### Correlation Co-efficient

# %%
corr_matrix1 = x_train1.corr()

# %%
upper_triangle1 = corr_matrix1.where(np.triu(np.ones(corr_matrix1.shape), k=1).astype(np.bool))
correlated_features_to_drop1 = [column for column in upper_triangle1.columns if any(upper_triangle1[column] > 0.5)]
# Out:
# <ipython-input-54-d932dfcaf7a7>:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper_triangle1 = corr_matrix1.where(np.triu(np.ones(corr_matrix1.shape), k=1).astype(np.bool))

# %%
print("Correlated features to drop:", correlated_features_to_drop1)
print("Number of features to drop:", len(correlated_features_to_drop1))
print("Number of features left:", 256 - len(correlated_features_to_drop1))
# Out:
# Correlated features to drop: ['feature_50', 'feature_57', 'feature_65', 'feature_73', 'feature_87', 'feature_93', 'feature_102', 'feature_105', 'feature_113', 'feature_145', 'feature_147', 'feature_148', 'feature_150', 'feature_165', 'feature_172', 'feature_177', 'feature_178', 'feature_182', 'feature_186', 'feature_206', 'feature_207', 'feature_208', 'feature_211', 'feature_219', 'feature_225', 'feature_233', 'feature_235', 'feature_238', 'feature_243', 'feature_244', 'feature_252', 'feature_256']
# Number of features to drop: 32
# Number of features left: 224

# %%
clf_cc = svm.SVC(kernel='linear')
clf_cc.fit(x_train1[x_train1.columns.difference(correlated_features_to_drop1)],y_train1)
y_pred = clf_cc.predict(x_valid1[x_valid1.columns.difference(correlated_features_to_drop1)])
print(f"Accuracy: ")
find_accuracy(y_pred,y_valid1)
# Out:
# Accuracy:
# accuracy_score 0.9906666666666667
# precision_score 0.9914237762237763
# recall_score 0.9906666666666667

# %% [markdown]
# ## Y_Test

# %%
mutual_info_selector = SelectKBest(mutual_info_classif, k=230)
x_train_mutual_info = mutual_info_selector.fit_transform(x_train1, y_train1)
x_valid_mutual_info = mutual_info_selector.transform(x_valid1)

print(f"Selected featured for k=230: ", x_train_mutual_info.shape[1])

pca = PCA(n_components=0.99, svd_solver='full')
pca.fit(x_train_mutual_info)
x_train_pca = pd.DataFrame(pca.transform(x_train_mutual_info))
x_valid_pca = pd.DataFrame(pca.transform(x_valid_mutual_info))
print(f"Selected featured: ", x_train_pca.shape[1])

clf_selected = svm.SVC(kernel='linear')
clf_selected.fit(x_train_pca,y_train1)
y_pred = clf_selected.predict(x_valid_pca)
print(f"Accuracies for n_components={0.99}: ")
find_accuracy(y_pred,y_valid1)
# Out:
# Selected featured for k=230:  230
# Selected featured:  103
# Accuracies for n_components=0.99:
# accuracy_score 0.992
# precision_score 0.992575730994152
# recall_score 0.992

# %%
test_df = test.drop(['label_1','label_2','label_3','label_4'],axis=1)

# %%
x_test1 = pd.DataFrame(scaler.transform(test_df),columns=FEATURES)

# %%
x_test_mutual_info = mutual_info_selector.transform(x_test1)

# %%
x_test_pca = pd.DataFrame(pca.transform(x_test_mutual_info))

# %%
test_pred = clf_selected.predict(x_test_pca)

# %%
x_test_pca
# Out:
#            0         1         2          3         4         5         6    \
# 0    -1.834567  6.597859 -1.901121   5.372679 -2.145857 -2.271058  5.010130
# 1    -6.951231  8.811956  0.188677  10.453268  0.235290  1.423622 -2.967384
# 2    -5.223718  3.468731 -0.300767   5.853362  2.053643 -1.512445 -1.595157
# 3    -2.382140  5.863609 -1.604375   0.308925 -0.659311  4.482410 -0.718629
# 4    -0.108921  5.995787  2.990394   4.003243  0.493726 -0.187735  1.730914
# ..         ...       ...       ...        ...       ...       ...       ...
# 745   1.249834 -1.242447 -7.160222  -2.488964  0.299787 -4.375637  1.297602
# 746  10.239151  4.536627 -0.559012   1.434208  0.138217  0.317445 -0.232246
# 747  -4.752242  2.480743 -3.263009  -0.116251 -1.929630  3.231968 -6.220845
# 748  -3.988759  3.630529  3.057401  -0.805790 -2.509332 -2.210600 -0.911500
# 749   3.350435  2.633189 -2.781670   2.271136 -3.610930 -5.333600  0.145254
#
#           7         8         9    ...       93        94        95   \
# 0   -1.610817  4.132909  3.439496  ...  0.268509 -0.770963  0.304098
# 1   -2.986189 -3.698068  6.834673  ...  0.804530 -0.378742 -0.218577
# 2   -0.518156 -6.147448  4.193908  ... -0.233677  0.096181  0.007561
# 3   -0.245774 -0.155834  7.025715  ...  0.008517 -0.068553  0.255260
# 4   -2.772702 -0.569574  6.352281  ... -0.304375 -0.464613 -0.376129
# ..        ...       ...       ...  ...       ...       ...       ...
# 745  3.305117 -1.798763  0.170001  ... -0.106282  0.192168 -0.166601
# 746  0.707908  0.585958 -2.507108  ... -0.108378 -0.106221 -0.220601
# 747  1.065927 -0.887683 -0.534123  ... -0.101228 -0.510224 -0.180385
# 748  1.538524  3.620213 -1.371357  ... -0.095951 -0.318281 -0.023716
# 749 -0.912803  0.428601  1.339248  ... -0.001781  0.177267 -0.193751
#
#           96        97        98        99        100       101       102
# 0    0.483783  0.014614  0.941625 -0.122090  0.035529  0.381037  0.158098
# 1    0.119046  0.227783 -0.418323 -0.294620  0.049350  0.094298 -0.266835
# 2    0.120071 -0.077656 -0.039688  0.114343  0.098322 -0.273586 -0.092853
# 3   -0.097954 -0.193629 -0.795846 -0.239842 -0.285810  0.136654  0.452534
# 4   -0.592971 -0.004067 -0.193668  0.038578  0.234232 -0.050549  0.319026
# ..        ...       ...       ...       ...       ...       ...       ...
# 745  0.148583 -0.029748  0.242329 -0.213606  0.154082  0.162101 -0.268555
# 746  0.049118 -0.146304 -0.154419 -0.581820  0.463701  0.136927  0.195709
# 747  0.354589  0.058424  0.100231  0.394508 -0.044348 -0.112701  0.330285
# 748  0.040416 -0.432236  0.622159  1.402466 -0.228508 -0.540617  0.321203
# 749 -0.508530  0.504039 -0.007654  0.438507  0.057017  0.352922 -0.283649
#
# [750 rows x 103 columns]

# %%
new_column_names = [f'new_feature_{i+1}' for i in range(x_test_pca.shape[1])]

# %%
x_test_pca.columns = new_column_names

# %%
x_test_pca.head()
# Out:
#    new_feature_1  new_feature_2  new_feature_3  new_feature_4  new_feature_5  \
# 0      -1.834567       6.597859      -1.901121       5.372679      -2.145857
# 1      -6.951231       8.811956       0.188677      10.453268       0.235290
# 2      -5.223718       3.468731      -0.300767       5.853362       2.053643
# 3      -2.382140       5.863609      -1.604375       0.308925      -0.659311
# 4      -0.108921       5.995787       2.990394       4.003243       0.493726
#
#    new_feature_6  new_feature_7  new_feature_8  new_feature_9  new_feature_10  \
# 0      -2.271058       5.010130      -1.610817       4.132909        3.439496
# 1       1.423622      -2.967384      -2.986189      -3.698068        6.834673
# 2      -1.512445      -1.595157      -0.518156      -6.147448        4.193908
# 3       4.482410      -0.718629      -0.245774      -0.155834        7.025715
# 4      -0.187735       1.730914      -2.772702      -0.569574        6.352281
#
#    ...  new_feature_94  new_feature_95  new_feature_96  new_feature_97  \
# 0  ...        0.268509       -0.770963        0.304098        0.483783
# 1  ...        0.804530       -0.378742       -0.218577        0.119046
# 2  ...       -0.233677        0.096181        0.007561        0.120071
# 3  ...        0.008517       -0.068553        0.255260       -0.097954
# 4  ...       -0.304375       -0.464613       -0.376129       -0.592971
#
#    new_feature_98  new_feature_99  new_feature_100  new_feature_101  \
# 0        0.014614        0.941625        -0.122090         0.035529
# 1        0.227783       -0.418323        -0.294620         0.049350
# 2       -0.077656       -0.039688         0.114343         0.098322
# 3       -0.193629       -0.795846        -0.239842        -0.285810
# 4       -0.004067       -0.193668         0.038578         0.234232
#
#    new_feature_102  new_feature_103
# 0         0.381037         0.158098
# 1         0.094298        -0.266835
# 2        -0.273586        -0.092853
# 3         0.136654         0.452534
# 4        -0.050549         0.319026
#
# [5 rows x 103 columns]

# %%
pred_df =  pd.DataFrame(test_pred, columns=["Predicted label_1 after feature engineering"])

# %%
clf = svm.SVC(kernel='linear')
clf.fit(x_train1,y_train1)
# Out:
# SVC(kernel='linear')

# %%
_y_pred_before = clf.predict(x_test1)

# %%
pred_df_before =  pd.DataFrame(_y_pred_before, columns=["Predicted label_1 before feature engineering"])

# %%
merged_df = pd.concat([x_test_pca, pred_df, pred_df_before], axis=1)

# %%
merged_df.head()
# Out:
#    new_feature_1  new_feature_2  new_feature_3  new_feature_4  new_feature_5  \
# 0      -1.834567       6.597859      -1.901121       5.372679      -2.145857
# 1      -6.951231       8.811956       0.188677      10.453268       0.235290
# 2      -5.223718       3.468731      -0.300767       5.853362       2.053643
# 3      -2.382140       5.863609      -1.604375       0.308925      -0.659311
# 4      -0.108921       5.995787       2.990394       4.003243       0.493726
#
#    new_feature_6  new_feature_7  new_feature_8  new_feature_9  new_feature_10  \
# 0      -2.271058       5.010130      -1.610817       4.132909        3.439496
# 1       1.423622      -2.967384      -2.986189      -3.698068        6.834673
# 2      -1.512445      -1.595157      -0.518156      -6.147448        4.193908
# 3       4.482410      -0.718629      -0.245774      -0.155834        7.025715
# 4      -0.187735       1.730914      -2.772702      -0.569574        6.352281
#
#    ...  new_feature_96  new_feature_97  new_feature_98  new_feature_99  \
# 0  ...        0.304098        0.483783        0.014614        0.941625
# 1  ...       -0.218577        0.119046        0.227783       -0.418323
# 2  ...        0.007561        0.120071       -0.077656       -0.039688
# 3  ...        0.255260       -0.097954       -0.193629       -0.795846
# 4  ...       -0.376129       -0.592971       -0.004067       -0.193668
#
#    new_feature_100  new_feature_101  new_feature_102  new_feature_103  \
# 0        -0.122090         0.035529         0.381037         0.158098
# 1        -0.294620         0.049350         0.094298        -0.266835
# 2         0.114343         0.098322        -0.273586        -0.092853
# 3        -0.239842        -0.285810         0.136654         0.452534
# 4         0.038578         0.234232        -0.050549         0.319026
#
#    Predicted label_1 after feature engineering  \
# 0                                           45
# 1                                           45
# 2                                           45
# 3                                           45
# 4                                           45
#
#    Predicted label_1 before feature engineering
# 0                                            45
# 1                                            45
# 2                                            45
# 3                                            45
# 4                                            45
#
# [5 rows x 105 columns]

# %%
merged_df.to_csv('190023G label 1.csv', index=False)
