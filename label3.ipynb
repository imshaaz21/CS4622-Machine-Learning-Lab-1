# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
train = pd.read_csv('/content/drive/MyDrive/CS4622 - Machine Learning/Lab 01/train.csv')
valid = pd.read_csv('/content/drive/MyDrive/CS4622 - Machine Learning/Lab 01/valid.csv')
test = pd.read_csv('/content/drive/MyDrive/CS4622 - Machine Learning/Lab 01/test.csv')

# %%
train.describe()
# Out:
#           feature_1     feature_2     feature_3     feature_4     feature_5  \
# count  28520.000000  28520.000000  28520.000000  28520.000000  28520.000000
# mean      -0.225478     -0.616421     -0.212878      0.336330      0.105467
# std        0.990632      1.005573      1.075468      1.248919      0.831132
# min       -4.023911     -5.582544     -4.679888     -4.284380     -3.010300
# 25%       -0.869656     -1.287018     -0.913419     -0.478661     -0.437171
# 50%       -0.190790     -0.609782     -0.218800      0.295881      0.117310
# 75%        0.457509      0.063174      0.490262      1.119242      0.657941
# max        4.322171      3.876604      4.267163      5.828656      3.884939
#
#           feature_6     feature_7     feature_8     feature_9    feature_10  \
# count  28520.000000  28520.000000  28520.000000  28520.000000  28520.000000
# mean      -0.339634     -0.201756      0.742262      0.942325     -1.957584
# std        1.073267      0.943505      1.055721      0.940459      0.876939
# min       -5.034355     -4.355222     -3.806574     -2.922614     -5.203347
# 25%       -1.075753     -0.823699      0.064072      0.298269     -2.556436
# 50%       -0.329571     -0.193263      0.755193      0.940786     -1.949847
# 75%        0.393339      0.417146      1.461846      1.579200     -1.345999
# max        3.890622      3.799406      4.817545      4.615069      1.147192
#
#        ...   feature_251   feature_252   feature_253   feature_254  \
# count  ...  28520.000000  28520.000000  28520.000000  28520.000000
# mean   ...     -0.028098      0.296340      1.724439     -1.476765
# std    ...      0.989497      1.173378      0.968611      1.032811
# min    ...     -3.679602     -3.905801     -3.301683     -5.490267
# 25%    ...     -0.692262     -0.550897      1.121631     -2.130906
# 50%    ...     -0.018218      0.295523      1.783432     -1.449978
# 75%    ...      0.644112      1.128566      2.383575     -0.799414
# max    ...      3.915582      4.458014      5.261775      2.861117
#
#         feature_255   feature_256       label_1       label_2       label_3  \
# count  28520.000000  28520.000000  28520.000000  28040.000000  28520.000000
# mean       0.687445     -1.563062     30.498843     27.975107      0.799299
# std        1.028328      1.243758     17.328389      5.735913      0.400532
# min       -3.810144     -6.056032      1.000000     22.000000      0.000000
# 25%       -0.008394     -2.404028     15.000000     25.000000      1.000000
# 50%        0.639575     -1.650610     30.000000     27.000000      1.000000
# 75%        1.347263     -0.805710     46.000000     30.000000      1.000000
# max        5.531152      3.338544     60.000000     61.000000      1.000000
#
#             label_4
# count  28520.000000
# mean       5.997125
# std        2.375567
# min        0.000000
# 25%        6.000000
# 50%        6.000000
# 75%        6.000000
# max       13.000000
#
# [8 rows x 260 columns]

# %%
valid.describe()
# Out:
#         feature_1   feature_2   feature_3   feature_4   feature_5   feature_6  \
# count  750.000000  750.000000  750.000000  750.000000  750.000000  750.000000
# mean    -0.215982   -0.623504   -0.291264    0.377151    0.178972   -0.252002
# std      0.956326    1.035303    1.128986    1.244136    0.843049    1.069149
# min     -3.600761   -5.998218   -3.933543   -3.788818   -2.352740   -4.067048
# 25%     -0.834711   -1.307291   -0.998405   -0.422144   -0.424725   -0.992993
# 50%     -0.205673   -0.607260   -0.307802    0.326517    0.190352   -0.196757
# 75%      0.417797    0.030387    0.412266    1.156195    0.757207    0.476947
# max      2.302163    2.441009    3.116088    4.058463    2.861698    2.790602
#
#         feature_7   feature_8   feature_9  feature_10  ...  feature_251  \
# count  750.000000  750.000000  750.000000  750.000000  ...   750.000000
# mean    -0.228841    0.771239    0.922442   -1.959988  ...    -0.051848
# std      0.955363    1.074252    0.947518    0.868173  ...     0.987202
# min     -3.307670   -3.230605   -2.501911   -4.732800  ...    -2.942192
# 25%     -0.916115    0.110733    0.323182   -2.508483  ...    -0.716455
# 50%     -0.212617    0.816087    0.910706   -1.918432  ...    -0.031057
# 75%      0.429078    1.482462    1.535642   -1.396017  ...     0.617642
# max      3.414155    4.249192    3.708912    0.418425  ...     3.356440
#
#        feature_252  feature_253  feature_254  feature_255  feature_256  \
# count   750.000000   750.000000   750.000000   750.000000   750.000000
# mean      0.342457     1.691002    -1.485593     0.691309    -1.567317
# std       1.141813     0.938246     1.051536     1.004137     1.268333
# min      -2.858132    -1.695706    -4.781263    -2.499728    -5.805717
# 25%      -0.491588     1.049466    -2.149493     0.035928    -2.459352
# 50%       0.333020     1.772243    -1.503996     0.620206    -1.634017
# 75%       1.135099     2.372264    -0.847414     1.324276    -0.752141
# max       3.532709     3.927659     2.039558     4.018772     2.496667
#
#           label_1     label_2     label_3     label_4
# count  750.000000  736.000000  750.000000  750.000000
# mean    30.085333   28.330163    0.810667    6.117333
# std     17.489060    6.518500    0.392035    2.227895
# min      1.000000   22.000000    0.000000    0.000000
# 25%     15.000000   25.000000    1.000000    6.000000
# 50%     29.000000   27.000000    1.000000    6.000000
# 75%     45.000000   30.000000    1.000000    6.000000
# max     60.000000   61.000000    1.000000   13.000000
#
# [8 rows x 260 columns]

# %%
FEATURES = [f'feature_{i}' for i in range(1,257)]

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##Label 03

# %%
train3 = train[FEATURES + ['label_3']].dropna()
valid3 = valid[FEATURES + ['label_3']]

# %%
train3.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0  -1.928826  -0.291540   1.105909   2.070652   0.657838  -0.670940
# 1  -1.709277  -1.008998   0.956611   4.313823  -0.669455   1.928765
# 2  -1.906183  -0.357562  -0.682627   4.651838  -0.884940   1.159512
# 3   0.697872  -2.218567  -0.572214   1.192062   0.329554   0.741364
# 4  -1.976895  -0.496308   0.368102   3.739787  -0.132058   1.234980
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_248  feature_249  \
# 0  -0.968238   0.049916   1.111149   -1.834592  ...     1.007398    -0.317517
# 1   0.162550   0.152173   2.356505   -2.898549  ...    -1.559120    -1.369495
# 2   1.354481  -1.432248   2.160144   -3.175735  ...    -0.136551    -2.210191
# 3   0.962354   0.993512   2.896854   -1.600380  ...    -0.718073    -2.546477
# 4  -0.501003   0.881554   1.630941   -3.853953  ...    -0.739541    -1.097638
#
#    feature_250  feature_251  feature_252  feature_253  feature_254  \
# 0    -0.148447    -0.691538    -1.152522     0.441157    -1.494434
# 1    -1.253272    -0.668235    -0.532695     0.151163    -1.876885
# 2    -1.463330    -0.026728     0.440408     2.745906    -0.680754
# 3    -2.172275     0.709032     0.812106     1.055266    -0.915258
# 4    -0.574205    -0.599700    -1.024829     1.869753    -2.498570
#
#    feature_255  feature_256  label_3
# 0    -0.344974    -0.395641        1
# 1     1.651534    -2.706490        1
# 2    -0.643588    -2.587203        1
# 3    -0.924856    -1.318964        1
# 4     3.268253    -1.356606        1
#
# [5 rows x 257 columns]

# %%
from sklearn import svm

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##  without any feature engineering

# %%
scaler = StandardScaler()

# %%
_x_train3 = train3.drop('label_3',axis=1)
y_train3 = train3['label_3']

_x_valid3 = valid3.drop('label_3',axis=1)
y_valid3 = valid3['label_3']

# %%
x_train3 = pd.DataFrame(scaler.fit_transform(_x_train3),columns=FEATURES)
x_valid3 = pd.DataFrame(scaler.transform(_x_valid3),columns=FEATURES)

# %%
clf = svm.SVC(kernel='linear')
clf.fit(x_train3,y_train3)
# Out:
# SVC(kernel='linear')

# %%
y_pred = clf.predict(x_valid3)

# %%
from sklearn import metrics

# %%
def find_accuracy(Y_pred,Y_valid):
  print(f"accuracy_score {metrics.accuracy_score(Y_valid,Y_pred)}")
  print(f"precision_score {metrics.precision_score(Y_valid,Y_pred,average='weighted')}")
  print(f"recall_score {metrics.recall_score(Y_valid,Y_pred,average='weighted')}")

# %%
find_accuracy(y_pred,y_valid3)
# Out:
# accuracy_score 0.9986666666666667
# precision_score 0.9986759906759908
# recall_score 0.9986666666666667

# %% [markdown]
# ## Feature selection

# %% [markdown]
# ### Mutual Information Feature selection

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif
import numpy as np

# %%
for k in [50,200,250]:
  mutual_info_selector = SelectKBest(mutual_info_classif, k=k)
  x_train_mutual_info = mutual_info_selector.fit_transform(x_train3, y_train3)
  print(f"Selected featured: ", x_train_mutual_info.shape[1])

  clf = svm.SVC(kernel='linear')
  clf.fit(x_train_mutual_info,y_train3)
  y_pred = clf.predict(mutual_info_selector.transform(x_valid3))

  print(f"Accuracies for k={k}: ")
  find_accuracy(y_pred,y_valid3)
# Out:
# Selected featured:  50
# Accuracies for k=50:
# accuracy_score 0.9933333333333333
# precision_score 0.9933209889482817
# recall_score 0.9933333333333333
# Selected featured:  200
# Accuracies for k=200:
# accuracy_score 1.0
# precision_score 1.0
# recall_score 1.0
# Selected featured:  250
# Accuracies for k=250:
# accuracy_score 0.9986666666666667
# precision_score 0.9986759906759908
# recall_score 0.9986666666666667

# %% [markdown]
# k = 230

# %%
mutual_info_selector = SelectKBest(mutual_info_classif, k=200)
x_train_mutual_info = mutual_info_selector.fit_transform(x_train3, y_train3)
print(f"Selected featured: ", x_train_mutual_info.shape[1])

clf = svm.SVC(kernel='linear')
clf.fit(x_train_mutual_info,y_train3)
y_pred = clf.predict(mutual_info_selector.transform(x_valid3))

print(f"Accuracies for k={200}: ")
find_accuracy(y_pred,y_valid3)
# Out:
# Selected featured:  200
# Accuracies for k=200:
# accuracy_score 1.0
# precision_score 1.0
# recall_score 1.0

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

# %%
for n in [0.95,0.99]:
  pca = PCA(n_components=n, svd_solver='full')
  pca.fit(x_train3)
  x_train_pca = pd.DataFrame(pca.transform(x_train3))
  x_valid_pca = pd.DataFrame(pca.transform(x_valid3))
  print(f"Selected featured: ", x_train_pca.shape[1])

  clf = svm.SVC(kernel='linear')
  clf.fit(x_train_pca,y_train3)
  y_pred = clf.predict(x_valid_pca)
  print(f"Accuracies for n_components={n}: ")
  find_accuracy(y_pred,y_valid3)
# Out:
# Selected featured:  67
# Accuracies for n_components=0.95:
# accuracy_score 0.9986666666666667
# precision_score 0.9986688560481665
# recall_score 0.9986666666666667
# Selected featured:  106
# Accuracies for n_components=0.99:
# accuracy_score 0.9986666666666667
# precision_score 0.9986759906759908
# recall_score 0.9986666666666667

# %% [markdown]
# ### Mutual Information Feature selection + PCA k=200, n_components=0.99

# %%
mutual_info_selector = SelectKBest(mutual_info_classif, k=200)
x_train_mutual_info = mutual_info_selector.fit_transform(x_train3, y_train3)
x_valid_mutual_info = mutual_info_selector.transform(x_valid3)
print(f"Selected featured for k=200: ", x_train_mutual_info.shape[1])

pca = PCA(n_components=0.95, svd_solver='full')
pca.fit(x_train_mutual_info)
x_train_pca = pd.DataFrame(pca.transform(x_train_mutual_info))
x_valid_pca = pd.DataFrame(pca.transform(x_valid_mutual_info))
print(f"Selected featured: ", x_train_pca.shape[1])

clf_selected = svm.SVC(kernel='linear')
clf_selected.fit(x_train_pca,y_train3)
y_pred = clf_selected.predict(x_valid_pca)
print(f"Accuracies for n_components={0.95}: ")
find_accuracy(y_pred,y_valid3)
# Out:
# Selected featured for k=200:  200
# Selected featured:  63
# Accuracies for n_components=0.95:
# accuracy_score 0.9986666666666667
# precision_score 0.9986688560481665
# recall_score 0.9986666666666667

# %% [markdown]
# ### Correlation Co-efficient

# %%
corr_matrix3 = x_train3.corr()

# %%
upper_triangle3 = corr_matrix3.where(np.triu(np.ones(corr_matrix3.shape), k=1).astype(np.bool))
correlated_features_to_drop3 = [column for column in upper_triangle3.columns if any(upper_triangle3[column] > 0.5)]
# Out:
# <ipython-input-119-a2f5cd12d05e>:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper_triangle3 = corr_matrix3.where(np.triu(np.ones(corr_matrix3.shape), k=1).astype(np.bool))

# %%
print("Correlated features to drop:", correlated_features_to_drop3)
print("Number of features to drop:", len(correlated_features_to_drop3))
print("Number of features left:", 256 - len(correlated_features_to_drop3))
# Out:
# Correlated features to drop: ['feature_50', 'feature_57', 'feature_65', 'feature_73', 'feature_87', 'feature_93', 'feature_102', 'feature_105', 'feature_113', 'feature_145', 'feature_147', 'feature_148', 'feature_150', 'feature_165', 'feature_172', 'feature_177', 'feature_178', 'feature_182', 'feature_186', 'feature_206', 'feature_207', 'feature_208', 'feature_211', 'feature_219', 'feature_225', 'feature_233', 'feature_235', 'feature_238', 'feature_243', 'feature_244', 'feature_252', 'feature_256']
# Number of features to drop: 32
# Number of features left: 224

# %%
clf_cc = svm.SVC(kernel='linear')
clf_cc.fit(x_train3[x_train3.columns.difference(correlated_features_to_drop3)],y_train3)
y_pred = clf_cc.predict(x_valid3[x_valid3.columns.difference(correlated_features_to_drop3)])
print(f"Accuracy: ")
find_accuracy(y_pred,y_valid3)
# Out:
# Accuracy:
# accuracy_score 0.9986666666666667
# precision_score 0.9986759906759908
# recall_score 0.9986666666666667

# %% [markdown]
# ## Y_Test

# %%
mutual_info_selector = SelectKBest(mutual_info_classif, k=200)
x_train_mutual_info = mutual_info_selector.fit_transform(x_train3, y_train3)
x_valid_mutual_info = mutual_info_selector.transform(x_valid3)

print(f"Selected featured for k=200: ", x_train_mutual_info.shape[1])

pca = PCA(n_components=0.95, svd_solver='full')
pca.fit(x_train_mutual_info)
x_train_pca = pd.DataFrame(pca.transform(x_train_mutual_info))
x_valid_pca = pd.DataFrame(pca.transform(x_valid_mutual_info))
print(f"Selected featured: ", x_train_pca.shape[1])

clf_selected = svm.SVC(kernel='linear')
clf_selected.fit(x_train_pca,y_train3)
y_pred = clf_selected.predict(x_valid_pca)
print(f"Accuracies for n_components={0.95}: ")
find_accuracy(y_pred,y_valid3)
# Out:
# Selected featured for k=200:  200
# Selected featured:  63
# Accuracies for n_components=0.95:
# accuracy_score 0.9986666666666667
# precision_score 0.9986688560481665
# recall_score 0.9986666666666667

# %%
test_df = test.drop(['label_1','label_2','label_3','label_4'],axis=1)

# %%
x_test3 = pd.DataFrame(scaler.transform(test_df),columns=FEATURES)

# %%
x_test_mutual_info = mutual_info_selector.transform(x_test3)

# %%
x_test_pca = pd.DataFrame(pca.transform(x_test_mutual_info))

# %%
test_pred = clf_selected.predict(x_test_pca)

# %%
x_test_pca
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.721382  5.951612 -2.792154 -4.726097 -1.507650  2.371607  5.407946
# 1    -6.183759  9.057873  1.555075 -6.176619  2.302550  6.751723 -0.241081
# 2    -4.966441  4.007841  0.091122 -4.476213  2.297352  0.797258 -0.118153
# 3    -1.755073  5.541913  1.444908  2.656684  2.444643  2.595384  0.424099
# 4     0.051544  5.628289  3.024274 -4.026275  0.650865  1.542693  3.160661
# ..         ...       ...       ...       ...       ...       ...       ...
# 745  -0.068225 -0.356197 -8.116989  1.742885 -1.183125 -3.811617  0.033120
# 746  10.038268  2.936693 -1.755465  0.023522  0.245150  1.441508  0.215360
# 747  -4.222312  2.899658 -2.147219  3.409027  0.017465  2.918225 -6.519665
# 748  -4.441824  3.447114  1.121109 -0.511179 -3.462337 -1.675278  0.125554
# 749   2.752433  2.395031 -5.156228 -3.765192 -4.518631  0.219781  0.484128
#
#            7         8         9   ...        53        54        55  \
# 0    1.333029  3.732486 -1.187649  ... -0.632666 -1.402900 -0.300615
# 1    1.875595 -3.368210 -5.264350  ... -1.239720 -0.473095  0.021972
# 2    0.365071 -5.886776 -2.629883  ... -0.353963 -1.081489  0.504393
# 3    1.915055  1.120172 -3.842544  ...  0.932711 -0.102039  0.351903
# 4    3.105890 -0.016292 -4.812049  ... -0.800935  0.076834 -0.559581
# ..        ...       ...       ...  ...       ...       ...       ...
# 745 -1.566249 -2.346148 -1.523370  ... -1.165052 -0.834223  0.789448
# 746 -1.429046 -1.186496  2.227963  ...  1.016996 -0.487708 -0.858407
# 747  0.216435  0.651397  0.310971  ... -0.510133 -0.359436  0.403141
# 748 -2.223204  3.679506  2.424246  ... -1.501418  1.226179  0.899178
# 749  0.888769  0.342154 -1.282315  ...  0.203490 -0.367406  0.137537
#
#            56        57        58        59        60        61        62
# 0    0.205259  1.213623 -0.066770  0.819028  0.125193  0.020996 -0.069030
# 1    0.137353 -1.178777  0.106531 -0.065007 -0.044724  0.211374 -0.283308
# 2    0.247764 -0.877072 -0.010635 -0.288721 -0.692522 -0.854453  0.017257
# 3    1.304928 -0.133663  0.421539 -0.084865  0.764249 -0.031305  0.510140
# 4    0.057783  0.214533  0.019586  0.427657  0.704760 -0.071905 -0.436669
# ..        ...       ...       ...       ...       ...       ...       ...
# 745 -0.719596  1.473188  2.119695  0.683961 -0.912027 -0.567208  0.125159
# 746 -0.038877 -0.597659 -0.119690  0.031874  0.064377 -1.942823  0.155046
# 747 -1.563806  1.373916 -0.410112 -0.166915 -0.023035  1.044485 -1.414006
# 748 -1.098126 -0.608903 -0.396556 -0.583956  1.786526  1.059052  0.396678
# 749 -0.402045  1.234858  0.977419 -0.562625  0.791141  0.201680 -0.284321
#
# [750 rows x 63 columns]

# %%
new_column_names = [f'new_feature_{i+1}' for i in range(x_test_pca.shape[1])]

# %%
x_test_pca.columns = new_column_names

# %%
x_test_pca.head()
# Out:
#    new_feature_1  new_feature_2  new_feature_3  new_feature_4  new_feature_5  \
# 0      -1.721382       5.951612      -2.792154      -4.726097      -1.507650
# 1      -6.183759       9.057873       1.555075      -6.176619       2.302550
# 2      -4.966441       4.007841       0.091122      -4.476213       2.297352
# 3      -1.755073       5.541913       1.444908       2.656684       2.444643
# 4       0.051544       5.628289       3.024274      -4.026275       0.650865
#
#    new_feature_6  new_feature_7  new_feature_8  new_feature_9  new_feature_10  \
# 0       2.371607       5.407946       1.333029       3.732486       -1.187649
# 1       6.751723      -0.241081       1.875595      -3.368210       -5.264350
# 2       0.797258      -0.118153       0.365071      -5.886776       -2.629883
# 3       2.595384       0.424099       1.915055       1.120172       -3.842544
# 4       1.542693       3.160661       3.105890      -0.016292       -4.812049
#
#    ...  new_feature_54  new_feature_55  new_feature_56  new_feature_57  \
# 0  ...       -0.632666       -1.402900       -0.300615        0.205259
# 1  ...       -1.239720       -0.473095        0.021972        0.137353
# 2  ...       -0.353963       -1.081489        0.504393        0.247764
# 3  ...        0.932711       -0.102039        0.351903        1.304928
# 4  ...       -0.800935        0.076834       -0.559581        0.057783
#
#    new_feature_58  new_feature_59  new_feature_60  new_feature_61  \
# 0        1.213623       -0.066770        0.819028        0.125193
# 1       -1.178777        0.106531       -0.065007       -0.044724
# 2       -0.877072       -0.010635       -0.288721       -0.692522
# 3       -0.133663        0.421539       -0.084865        0.764249
# 4        0.214533        0.019586        0.427657        0.704760
#
#    new_feature_62  new_feature_63
# 0        0.020996       -0.069030
# 1        0.211374       -0.283308
# 2       -0.854453        0.017257
# 3       -0.031305        0.510140
# 4       -0.071905       -0.436669
#
# [5 rows x 63 columns]

# %%
pred_df =  pd.DataFrame(test_pred, columns=["Predicted label_3 after feature engineering"])

# %%
clf = svm.SVC(kernel='linear')
clf.fit(x_train3,y_train3)
# Out:
# SVC(kernel='linear')

# %%
_y_pred_before = clf.predict(x_test3)

# %%
pred_df_before =  pd.DataFrame(_y_pred_before, columns=["Predicted label_3 before feature engineering"])

# %%
merged_df = pd.concat([x_test_pca, pred_df, pred_df_before], axis=1)

# %%
merged_df.head()
# Out:
#    new_feature_1  new_feature_2  new_feature_3  new_feature_4  new_feature_5  \
# 0      -1.721382       5.951612      -2.792154      -4.726097      -1.507650
# 1      -6.183759       9.057873       1.555075      -6.176619       2.302550
# 2      -4.966441       4.007841       0.091122      -4.476213       2.297352
# 3      -1.755073       5.541913       1.444908       2.656684       2.444643
# 4       0.051544       5.628289       3.024274      -4.026275       0.650865
#
#    new_feature_6  new_feature_7  new_feature_8  new_feature_9  new_feature_10  \
# 0       2.371607       5.407946       1.333029       3.732486       -1.187649
# 1       6.751723      -0.241081       1.875595      -3.368210       -5.264350
# 2       0.797258      -0.118153       0.365071      -5.886776       -2.629883
# 3       2.595384       0.424099       1.915055       1.120172       -3.842544
# 4       1.542693       3.160661       3.105890      -0.016292       -4.812049
#
#    ...  new_feature_56  new_feature_57  new_feature_58  new_feature_59  \
# 0  ...       -0.300615        0.205259        1.213623       -0.066770
# 1  ...        0.021972        0.137353       -1.178777        0.106531
# 2  ...        0.504393        0.247764       -0.877072       -0.010635
# 3  ...        0.351903        1.304928       -0.133663        0.421539
# 4  ...       -0.559581        0.057783        0.214533        0.019586
#
#    new_feature_60  new_feature_61  new_feature_62  new_feature_63  \
# 0        0.819028        0.125193        0.020996       -0.069030
# 1       -0.065007       -0.044724        0.211374       -0.283308
# 2       -0.288721       -0.692522       -0.854453        0.017257
# 3       -0.084865        0.764249       -0.031305        0.510140
# 4        0.427657        0.704760       -0.071905       -0.436669
#
#    Predicted label_3 after feature engineering  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
#
#    Predicted label_3 before feature engineering
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
#
# [5 rows x 65 columns]

# %%
merged_df.to_csv('190023G label 3.csv', index=False)
