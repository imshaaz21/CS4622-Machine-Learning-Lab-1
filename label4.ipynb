# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
train = pd.read_csv('/content/drive/MyDrive/CS4622 - Machine Learning/Lab 01/train.csv')
valid = pd.read_csv('/content/drive/MyDrive/CS4622 - Machine Learning/Lab 01/valid.csv')
test = pd.read_csv('/content/drive/MyDrive/CS4622 - Machine Learning/Lab 01/test.csv')

# %%
train.describe()
# Out:
#           feature_1     feature_2     feature_3     feature_4     feature_5  \
# count  28520.000000  28520.000000  28520.000000  28520.000000  28520.000000
# mean      -0.225478     -0.616421     -0.212878      0.336330      0.105467
# std        0.990632      1.005573      1.075468      1.248919      0.831132
# min       -4.023911     -5.582544     -4.679888     -4.284380     -3.010300
# 25%       -0.869656     -1.287018     -0.913419     -0.478661     -0.437171
# 50%       -0.190790     -0.609782     -0.218800      0.295881      0.117310
# 75%        0.457509      0.063174      0.490262      1.119242      0.657941
# max        4.322171      3.876604      4.267163      5.828656      3.884939
#
#           feature_6     feature_7     feature_8     feature_9    feature_10  \
# count  28520.000000  28520.000000  28520.000000  28520.000000  28520.000000
# mean      -0.339634     -0.201756      0.742262      0.942325     -1.957584
# std        1.073267      0.943505      1.055721      0.940459      0.876939
# min       -5.034355     -4.355222     -3.806574     -2.922614     -5.203347
# 25%       -1.075753     -0.823699      0.064072      0.298269     -2.556436
# 50%       -0.329571     -0.193263      0.755193      0.940786     -1.949847
# 75%        0.393339      0.417146      1.461846      1.579200     -1.345999
# max        3.890622      3.799406      4.817545      4.615069      1.147192
#
#        ...   feature_251   feature_252   feature_253   feature_254  \
# count  ...  28520.000000  28520.000000  28520.000000  28520.000000
# mean   ...     -0.028098      0.296340      1.724439     -1.476765
# std    ...      0.989497      1.173378      0.968611      1.032811
# min    ...     -3.679602     -3.905801     -3.301683     -5.490267
# 25%    ...     -0.692262     -0.550897      1.121631     -2.130906
# 50%    ...     -0.018218      0.295523      1.783432     -1.449978
# 75%    ...      0.644112      1.128566      2.383575     -0.799414
# max    ...      3.915582      4.458014      5.261775      2.861117
#
#         feature_255   feature_256       label_1       label_2       label_3  \
# count  28520.000000  28520.000000  28520.000000  28040.000000  28520.000000
# mean       0.687445     -1.563062     30.498843     27.975107      0.799299
# std        1.028328      1.243758     17.328389      5.735913      0.400532
# min       -3.810144     -6.056032      1.000000     22.000000      0.000000
# 25%       -0.008394     -2.404028     15.000000     25.000000      1.000000
# 50%        0.639575     -1.650610     30.000000     27.000000      1.000000
# 75%        1.347263     -0.805710     46.000000     30.000000      1.000000
# max        5.531152      3.338544     60.000000     61.000000      1.000000
#
#             label_4
# count  28520.000000
# mean       5.997125
# std        2.375567
# min        0.000000
# 25%        6.000000
# 50%        6.000000
# 75%        6.000000
# max       13.000000
#
# [8 rows x 260 columns]

# %%
valid.describe()
# Out:
#         feature_1   feature_2   feature_3   feature_4   feature_5   feature_6  \
# count  750.000000  750.000000  750.000000  750.000000  750.000000  750.000000
# mean    -0.215982   -0.623504   -0.291264    0.377151    0.178972   -0.252002
# std      0.956326    1.035303    1.128986    1.244136    0.843049    1.069149
# min     -3.600761   -5.998218   -3.933543   -3.788818   -2.352740   -4.067048
# 25%     -0.834711   -1.307291   -0.998405   -0.422144   -0.424725   -0.992993
# 50%     -0.205673   -0.607260   -0.307802    0.326517    0.190352   -0.196757
# 75%      0.417797    0.030387    0.412266    1.156195    0.757207    0.476947
# max      2.302163    2.441009    3.116088    4.058463    2.861698    2.790602
#
#         feature_7   feature_8   feature_9  feature_10  ...  feature_251  \
# count  750.000000  750.000000  750.000000  750.000000  ...   750.000000
# mean    -0.228841    0.771239    0.922442   -1.959988  ...    -0.051848
# std      0.955363    1.074252    0.947518    0.868173  ...     0.987202
# min     -3.307670   -3.230605   -2.501911   -4.732800  ...    -2.942192
# 25%     -0.916115    0.110733    0.323182   -2.508483  ...    -0.716455
# 50%     -0.212617    0.816087    0.910706   -1.918432  ...    -0.031057
# 75%      0.429078    1.482462    1.535642   -1.396017  ...     0.617642
# max      3.414155    4.249192    3.708912    0.418425  ...     3.356440
#
#        feature_252  feature_253  feature_254  feature_255  feature_256  \
# count   750.000000   750.000000   750.000000   750.000000   750.000000
# mean      0.342457     1.691002    -1.485593     0.691309    -1.567317
# std       1.141813     0.938246     1.051536     1.004137     1.268333
# min      -2.858132    -1.695706    -4.781263    -2.499728    -5.805717
# 25%      -0.491588     1.049466    -2.149493     0.035928    -2.459352
# 50%       0.333020     1.772243    -1.503996     0.620206    -1.634017
# 75%       1.135099     2.372264    -0.847414     1.324276    -0.752141
# max       3.532709     3.927659     2.039558     4.018772     2.496667
#
#           label_1     label_2     label_3     label_4
# count  750.000000  736.000000  750.000000  750.000000
# mean    30.085333   28.330163    0.810667    6.117333
# std     17.489060    6.518500    0.392035    2.227895
# min      1.000000   22.000000    0.000000    0.000000
# 25%     15.000000   25.000000    1.000000    6.000000
# 50%     29.000000   27.000000    1.000000    6.000000
# 75%     45.000000   30.000000    1.000000    6.000000
# max     60.000000   61.000000    1.000000   13.000000
#
# [8 rows x 260 columns]

# %%
FEATURES = [f'feature_{i}' for i in range(1,257)]

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##Label 04

# %%
train4 = train[FEATURES + ['label_4']].dropna()
valid4 = valid[FEATURES + ['label_4']]

# %%
train4.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0  -1.928826  -0.291540   1.105909   2.070652   0.657838  -0.670940
# 1  -1.709277  -1.008998   0.956611   4.313823  -0.669455   1.928765
# 2  -1.906183  -0.357562  -0.682627   4.651838  -0.884940   1.159512
# 3   0.697872  -2.218567  -0.572214   1.192062   0.329554   0.741364
# 4  -1.976895  -0.496308   0.368102   3.739787  -0.132058   1.234980
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_248  feature_249  \
# 0  -0.968238   0.049916   1.111149   -1.834592  ...     1.007398    -0.317517
# 1   0.162550   0.152173   2.356505   -2.898549  ...    -1.559120    -1.369495
# 2   1.354481  -1.432248   2.160144   -3.175735  ...    -0.136551    -2.210191
# 3   0.962354   0.993512   2.896854   -1.600380  ...    -0.718073    -2.546477
# 4  -0.501003   0.881554   1.630941   -3.853953  ...    -0.739541    -1.097638
#
#    feature_250  feature_251  feature_252  feature_253  feature_254  \
# 0    -0.148447    -0.691538    -1.152522     0.441157    -1.494434
# 1    -1.253272    -0.668235    -0.532695     0.151163    -1.876885
# 2    -1.463330    -0.026728     0.440408     2.745906    -0.680754
# 3    -2.172275     0.709032     0.812106     1.055266    -0.915258
# 4    -0.574205    -0.599700    -1.024829     1.869753    -2.498570
#
#    feature_255  feature_256  label_4
# 0    -0.344974    -0.395641        6
# 1     1.651534    -2.706490        6
# 2    -0.643588    -2.587203        6
# 3    -0.924856    -1.318964        6
# 4     3.268253    -1.356606        6
#
# [5 rows x 257 columns]

# %%
from sklearn import svm

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##  without any feature engineering

# %%
scaler = StandardScaler()

# %%
_x_train4 = train4.drop('label_4',axis=1)
y_train4 = train4['label_4']

_x_valid4 = valid4.drop('label_4',axis=1)
y_valid4 = valid4['label_4']

# %%
x_train4 = pd.DataFrame(scaler.fit_transform(_x_train4),columns=FEATURES)
x_valid4 = pd.DataFrame(scaler.transform(_x_valid4),columns=FEATURES)

# %%
clf = svm.SVC(kernel='linear')
clf.fit(x_train4,y_train4)
# Out:
# SVC(kernel='linear')

# %%
y_pred = clf.predict(x_valid4)

# %%
from sklearn import metrics

# %%
def find_accuracy(Y_pred,Y_valid):
  print(f"accuracy_score {metrics.accuracy_score(Y_valid,Y_pred)}")
  print(f"precision_score {metrics.precision_score(Y_valid,Y_pred,average='weighted')}")
  print(f"recall_score {metrics.recall_score(Y_valid,Y_pred,average='weighted')}")

# %%
find_accuracy(y_pred,y_valid4)
# Out:
# accuracy_score 0.9626666666666667
# precision_score 0.9640391492190096
# recall_score 0.9626666666666667

# %% [markdown]
# ## Feature selection

# %% [markdown]
# ### Mutual Information Feature selection

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif
import numpy as np

# %%
for k in [50,100,150,200,250]:
  mutual_info_selector = SelectKBest(mutual_info_classif, k=k)
  x_train_mutual_info = mutual_info_selector.fit_transform(x_train4, y_train4)
  print(f"Selected featured: ", x_train_mutual_info.shape[1])

  clf = svm.SVC(kernel='linear')
  clf.fit(x_train_mutual_info,y_train4)
  y_pred = clf.predict(mutual_info_selector.transform(x_valid4))

  print(f"Accuracies for k={k}: ")
  find_accuracy(y_pred,y_valid4)
# Out:
# Selected featured:  50
# Accuracies for k=50:
# accuracy_score 0.8666666666666667
# precision_score 0.8709880169062544
# recall_score 0.8666666666666667
# Selected featured:  100
# Accuracies for k=100:
# accuracy_score 0.9266666666666666
# precision_score 0.9251052134793313
# recall_score 0.9266666666666666
# Selected featured:  150
# Accuracies for k=150:
# accuracy_score 0.9426666666666667
# precision_score 0.9429127662176688
# recall_score 0.9426666666666667
# Selected featured:  200
# Accuracies for k=200:
# accuracy_score 0.9466666666666667
# precision_score 0.947520052784553
# recall_score 0.9466666666666667
# Selected featured:  250
# Accuracies for k=250:
# accuracy_score 0.9586666666666667
# precision_score 0.9601010968432316
# recall_score 0.9586666666666667

# %% [markdown]
# k = 230

# %%
for k in [225,230,240]:
  mutual_info_selector = SelectKBest(mutual_info_classif, k=k)
  x_train_mutual_info = mutual_info_selector.fit_transform(x_train4, y_train4)
  print(f"Selected featured: ", x_train_mutual_info.shape[1])

  clf = svm.SVC(kernel='linear')
  clf.fit(x_train_mutual_info,y_train4)
  y_pred = clf.predict(mutual_info_selector.transform(x_valid4))

  print(f"Accuracies for k={k}: ")
  find_accuracy(y_pred,y_valid4)
# Out:
# Selected featured:  225
# Accuracies for k=225:
# accuracy_score 0.9546666666666667
# precision_score 0.9562597289567706
# recall_score 0.9546666666666667
# Selected featured:  230
# Accuracies for k=230:
# accuracy_score 0.952
# precision_score 0.9537368257373076
# recall_score 0.952
# Selected featured:  240
# Accuracies for k=240:
# accuracy_score 0.9533333333333334
# precision_score 0.9552160602391082
# recall_score 0.9533333333333334

# %%
mutual_info_selector = SelectKBest(mutual_info_classif, k=225)
x_train_mutual_info = mutual_info_selector.fit_transform(x_train4, y_train4)
print(f"Selected featured: ", x_train_mutual_info.shape[1])

clf = svm.SVC(kernel='linear')
clf.fit(x_train_mutual_info,y_train4)
y_pred = clf.predict(mutual_info_selector.transform(x_valid4))

print(f"Accuracies for k={225}: ")
find_accuracy(y_pred,y_valid4)
# Out:
# Selected featured:  225
# Accuracies for k=225:
# accuracy_score 0.9546666666666667
# precision_score 0.9562597289567706
# recall_score 0.9546666666666667

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

# %%
for n in [0.95,0.99]:
  pca = PCA(n_components=n, svd_solver='full')
  pca.fit(x_train4)
  x_train_pca = pd.DataFrame(pca.transform(x_train4))
  x_valid_pca = pd.DataFrame(pca.transform(x_valid4))
  print(f"Selected featured: ", x_train_pca.shape[1])

  clf = svm.SVC(kernel='linear')
  clf.fit(x_train_pca,y_train4)
  y_pred = clf.predict(x_valid_pca)
  print(f"Accuracies for n_components={n}: ")
  find_accuracy(y_pred,y_valid4)
# Out:
# Selected featured:  67
# Accuracies for n_components=0.95:
# accuracy_score 0.908
# precision_score 0.9039145496796468
# recall_score 0.908
# Selected featured:  106
# Accuracies for n_components=0.99:
# accuracy_score 0.9333333333333333
# precision_score 0.9330345074678409
# recall_score 0.9333333333333333

# %% [markdown]
# ### Mutual Information Feature selection + PCA k=225, n_components=0.99

# %%
mutual_info_selector = SelectKBest(mutual_info_classif, k=225)
x_train_mutual_info = mutual_info_selector.fit_transform(x_train4, y_train4)
x_valid_mutual_info = mutual_info_selector.transform(x_valid4)
print(f"Selected featured for k=225: ", x_train_mutual_info.shape[1])

pca = PCA(n_components=0.99, svd_solver='full')
pca.fit(x_train_mutual_info)
x_train_pca = pd.DataFrame(pca.transform(x_train_mutual_info))
x_valid_pca = pd.DataFrame(pca.transform(x_valid_mutual_info))
print(f"Selected featured: ", x_train_pca.shape[1])

clf_selected = svm.SVC(kernel='linear')
clf_selected.fit(x_train_pca,y_train4)
y_pred = clf_selected.predict(x_valid_pca)
print(f"Accuracies for n_components={0.99}: ")
find_accuracy(y_pred,y_valid4)
# Out:
# Selected featured for k=225:  225
# Selected featured:  103
# Accuracies for n_components=0.99:
# accuracy_score 0.9386666666666666
# precision_score 0.9389357239746364
# recall_score 0.9386666666666666

# %% [markdown]
# ### Correlation Co-efficient

# %%
corr_matrix4 = x_train4.corr()

# %%
upper_triangle4 = corr_matrix4.where(np.triu(np.ones(corr_matrix4.shape), k=1).astype(np.bool))
correlated_features_to_drop4 = [column for column in upper_triangle4.columns if any(upper_triangle4[column] > 0.5)]
# Out:
# <ipython-input-62-ffcbd47ed79b>:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper_triangle4 = corr_matrix4.where(np.triu(np.ones(corr_matrix4.shape), k=1).astype(np.bool))

# %%
print("Correlated features to drop:", correlated_features_to_drop4)
print("Number of features to drop:", len(correlated_features_to_drop4))
print("Number of features left:", 256 - len(correlated_features_to_drop4))
# Out:
# Correlated features to drop: ['feature_50', 'feature_57', 'feature_65', 'feature_73', 'feature_87', 'feature_93', 'feature_102', 'feature_105', 'feature_113', 'feature_145', 'feature_147', 'feature_148', 'feature_150', 'feature_165', 'feature_172', 'feature_177', 'feature_178', 'feature_182', 'feature_186', 'feature_206', 'feature_207', 'feature_208', 'feature_211', 'feature_219', 'feature_225', 'feature_233', 'feature_235', 'feature_238', 'feature_243', 'feature_244', 'feature_252', 'feature_256']
# Number of features to drop: 32
# Number of features left: 224

# %%
clf_cc = svm.SVC(kernel='linear')
clf_cc.fit(x_train4[x_train4.columns.difference(correlated_features_to_drop4)],y_train4)
y_pred = clf_cc.predict(x_valid4[x_valid4.columns.difference(correlated_features_to_drop4)])
print(f"Accuracy: ")
find_accuracy(y_pred,y_valid4)
# Out:
# Accuracy:
# accuracy_score 0.9533333333333334
# precision_score 0.9543470096011812
# recall_score 0.9533333333333334

# %% [markdown]
# ## Y_Test

# %%
mutual_info_selector = SelectKBest(mutual_info_classif, k=225)
x_train_mutual_info = mutual_info_selector.fit_transform(x_train4, y_train4)
x_valid_mutual_info = mutual_info_selector.transform(x_valid4)

print(f"Selected featured for k=230: ", x_train_mutual_info.shape[1])

pca = PCA(n_components=0.99, svd_solver='full')
pca.fit(x_train_mutual_info)
x_train_pca = pd.DataFrame(pca.transform(x_train_mutual_info))
x_valid_pca = pd.DataFrame(pca.transform(x_valid_mutual_info))
print(f"Selected featured: ", x_train_pca.shape[1])

clf_selected = svm.SVC(kernel='linear')
clf_selected.fit(x_train_pca,y_train4)
y_pred = clf_selected.predict(x_valid_pca)
print(f"Accuracies for n_components={0.99}: ")
find_accuracy(y_pred,y_valid4)
# Out:
# Selected featured for k=230:  225
# Selected featured:  103
# Accuracies for n_components=0.99:
# accuracy_score 0.9373333333333334
# precision_score 0.9362731516018256
# recall_score 0.9373333333333334

# %%
test_df = test.drop(['label_1','label_2','label_3','label_4'],axis=1)

# %%
x_test4 = pd.DataFrame(scaler.transform(test_df),columns=FEATURES)

# %%
x_test_mutual_info = mutual_info_selector.transform(x_test4)

# %%
x_test_pca = pd.DataFrame(pca.transform(x_test_mutual_info))

# %%
test_pred = clf_selected.predict(x_test_pca)

# %%
x_test_pca
# Out:
#            0         1         2         3         4         5         6    \
# 0    -1.719392  6.299507 -2.655269  2.107848 -6.293115 -1.739570  5.139453
# 1    -6.736849  8.829949  2.526321  8.854005 -5.466367  4.296169 -0.598314
# 2    -4.894055  3.705999  1.133015  5.703665 -2.282818 -0.572039  0.029484
# 3    -2.448801  5.675214 -0.114845 -0.748478  1.084532  3.642164 -0.009335
# 4     0.259162  6.166685  2.492291  3.943681 -2.349941 -0.101900  3.330567
# ..         ...       ...       ...       ...       ...       ...       ...
# 745   0.592723 -0.915673 -7.585574 -1.883960  0.327689 -4.617945 -0.477311
# 746  10.399321  4.287394 -1.100600  1.098103 -0.501255  0.545485 -0.165975
# 747  -5.299459  2.364478 -1.212682 -1.303119 -0.021336  4.164289 -6.099344
# 748  -3.045896  2.850779  2.995159 -3.810444 -1.843717 -3.691486 -0.498548
# 749   3.466065  2.928450 -3.667232 -0.423087 -6.138692 -3.685222 -0.168205
#
#           7         8         9    ...       93        94        95   \
# 0    4.084324  4.129348 -1.737234  ... -0.255365  0.322698 -0.501750
# 1   -2.009995  1.126246 -6.409130  ... -0.488519  0.721035 -0.084078
# 2   -2.768577 -2.421407 -5.382274  ... -0.624436  0.165645  0.273019
# 3    0.932197  2.427669 -5.930725  ... -0.185070  0.585233 -0.151211
# 4    0.815326  3.538244 -5.634655  ...  0.049944 -0.176157  0.054249
# ..        ...       ...       ...  ...       ...       ...       ...
# 745  1.360501 -3.553066 -1.354010  ...  0.210922 -0.056989 -0.278747
# 746  0.914282 -2.108914  3.003117  ...  0.481758  0.068627  0.309766
# 747 -1.661019 -1.039776 -0.374199  ...  0.252141  0.456803 -0.032808
# 748  1.797893  1.609997  2.504515  ... -0.468854  0.016283  0.096351
# 749  0.046951  0.608962 -1.007910  ...  0.491357 -0.043690 -0.298197
#
#           96        97        98        99        100       101       102
# 0   -0.037781  0.027015 -0.149355  0.317303 -0.192802 -0.370205  0.027162
# 1    0.094003 -0.112508  0.017760 -0.000200 -0.361227  0.100136 -0.090810
# 2   -0.268752  0.083388  0.332078 -0.289808  0.473264 -0.266747 -0.105832
# 3   -0.306676  0.002025 -0.599843  0.248233 -0.043671  0.694851 -0.823919
# 4    0.537695 -0.084259 -0.018412 -0.286356 -0.233177  0.024728  0.137223
# ..        ...       ...       ...       ...       ...       ...       ...
# 745 -0.242499 -0.252160  0.471296 -0.182602 -0.286866  0.004440  0.086517
# 746 -0.006373  0.087352  0.341854 -0.444100  0.113477 -0.034460  0.442856
# 747  0.456576 -0.197138 -0.153821 -0.121590 -0.062952 -0.366998  0.445046
# 748  0.363833 -0.591664  0.677581  0.535463 -0.091698  0.341676  0.860688
# 749  0.249041  0.005791  0.758499  0.012597 -0.900555  0.407435  0.061641
#
# [750 rows x 103 columns]

# %%
new_column_names = [f'new_feature_{i+1}' for i in range(x_test_pca.shape[1])]

# %%
x_test_pca.columns = new_column_names

# %%
x_test_pca.head()
# Out:
#    new_feature_1  new_feature_2  new_feature_3  new_feature_4  new_feature_5  \
# 0      -1.719392       6.299507      -2.655269       2.107848      -6.293115
# 1      -6.736849       8.829949       2.526321       8.854005      -5.466367
# 2      -4.894055       3.705999       1.133015       5.703665      -2.282818
# 3      -2.448801       5.675214      -0.114845      -0.748478       1.084532
# 4       0.259162       6.166685       2.492291       3.943681      -2.349941
#
#    new_feature_6  new_feature_7  new_feature_8  new_feature_9  new_feature_10  \
# 0      -1.739570       5.139453       4.084324       4.129348       -1.737234
# 1       4.296169      -0.598314      -2.009995       1.126246       -6.409130
# 2      -0.572039       0.029484      -2.768577      -2.421407       -5.382274
# 3       3.642164      -0.009335       0.932197       2.427669       -5.930725
# 4      -0.101900       3.330567       0.815326       3.538244       -5.634655
#
#    ...  new_feature_94  new_feature_95  new_feature_96  new_feature_97  \
# 0  ...       -0.255365        0.322698       -0.501750       -0.037781
# 1  ...       -0.488519        0.721035       -0.084078        0.094003
# 2  ...       -0.624436        0.165645        0.273019       -0.268752
# 3  ...       -0.185070        0.585233       -0.151211       -0.306676
# 4  ...        0.049944       -0.176157        0.054249        0.537695
#
#    new_feature_98  new_feature_99  new_feature_100  new_feature_101  \
# 0        0.027015       -0.149355         0.317303        -0.192802
# 1       -0.112508        0.017760        -0.000200        -0.361227
# 2        0.083388        0.332078        -0.289808         0.473264
# 3        0.002025       -0.599843         0.248233        -0.043671
# 4       -0.084259       -0.018412        -0.286356        -0.233177
#
#    new_feature_102  new_feature_103
# 0        -0.370205         0.027162
# 1         0.100136        -0.090810
# 2        -0.266747        -0.105832
# 3         0.694851        -0.823919
# 4         0.024728         0.137223
#
# [5 rows x 103 columns]

# %%
pred_df =  pd.DataFrame(test_pred, columns=["Predicted labels after feature engineering"])

# %%
clf = svm.SVC(kernel='linear')
clf.fit(x_train4,y_train4)
# Out:
# SVC(kernel='linear')

# %%
_y_pred_before = clf.predict(x_test4)

# %%
pred_df_before =  pd.DataFrame(_y_pred_before, columns=["Predicted labels before feature engineering"])

# %%
merged_df = pd.concat([x_test_pca, pred_df, pred_df_before], axis=1)

# %%
merged_df.head()
# Out:
#    new_feature_1  new_feature_2  new_feature_3  new_feature_4  new_feature_5  \
# 0      -1.719392       6.299507      -2.655269       2.107848      -6.293115
# 1      -6.736849       8.829949       2.526321       8.854005      -5.466367
# 2      -4.894055       3.705999       1.133015       5.703665      -2.282818
# 3      -2.448801       5.675214      -0.114845      -0.748478       1.084532
# 4       0.259162       6.166685       2.492291       3.943681      -2.349941
#
#    new_feature_6  new_feature_7  new_feature_8  new_feature_9  new_feature_10  \
# 0      -1.739570       5.139453       4.084324       4.129348       -1.737234
# 1       4.296169      -0.598314      -2.009995       1.126246       -6.409130
# 2      -0.572039       0.029484      -2.768577      -2.421407       -5.382274
# 3       3.642164      -0.009335       0.932197       2.427669       -5.930725
# 4      -0.101900       3.330567       0.815326       3.538244       -5.634655
#
#    ...  new_feature_96  new_feature_97  new_feature_98  new_feature_99  \
# 0  ...       -0.501750       -0.037781        0.027015       -0.149355
# 1  ...       -0.084078        0.094003       -0.112508        0.017760
# 2  ...        0.273019       -0.268752        0.083388        0.332078
# 3  ...       -0.151211       -0.306676        0.002025       -0.599843
# 4  ...        0.054249        0.537695       -0.084259       -0.018412
#
#    new_feature_100  new_feature_101  new_feature_102  new_feature_103  \
# 0         0.317303        -0.192802        -0.370205         0.027162
# 1        -0.000200        -0.361227         0.100136        -0.090810
# 2        -0.289808         0.473264        -0.266747        -0.105832
# 3         0.248233        -0.043671         0.694851        -0.823919
# 4        -0.286356        -0.233177         0.024728         0.137223
#
#    Predicted labels after feature engineering  \
# 0                                           6
# 1                                           6
# 2                                           6
# 3                                           6
# 4                                           6
#
#    Predicted labels before feature engineering
# 0                                            6
# 1                                            6
# 2                                            6
# 3                                            6
# 4                                            6
#
# [5 rows x 105 columns]

# %%
merged_df.to_csv('190023G_label_4.csv', index=False)
